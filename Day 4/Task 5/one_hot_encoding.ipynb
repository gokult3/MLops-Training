# %%
import pandas as pd
df = pd.read_csv("one_hot_encoding.csv")
df
# Out:
#                 Car Model  Mileage  Age(yrs)  Sell Price($)
# 0                  BMW X5    69000         6          18000
# 1                  BMW X5    35000         3          34000
# 2                  BMW X5    57000         5          26100
# 3                  BMW X5    22500         2          40000
# 4                  BMW X5    46000         4          31500
# 5                 Audi A5    59000         5          29400
# 6                 Audi A5    52000         5          32000
# 7                 Audi A5    72000         6          19300
# 8                 Audi A5    91000         8          12000
# 9                 Audi A5    67000         6          22000
# 10  Mercedez Benz C class    83000         7          20000
# 11  Mercedez Benz C class    79000         7          21000
# 12  Mercedez Benz C class    59000         5          33000
# 13  Mercedez Benz C class    58780         4          27500
# 14  Mercedez Benz C class    82450         7          19400
# 15  Mercedez Benz C class    25400         3          40500

# %%
dummies = pd.get_dummies(df['Car Model'])

print(dummies)
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0     False    True                  False
# 1     False    True                  False
# 2     False    True                  False
# 3     False    True                  False
# 4     False    True                  False
# 5      True   False                  False
# 6      True   False                  False
# 7      True   False                  False
# 8      True   False                  False
# 9      True   False                  False
# 10    False   False                   True
# 11    False   False                   True
# 12    False   False                   True
# 13    False   False                   True
# 14    False   False                   True
# 15    False   False                   True

# %%
merged = pd.concat([df,dummies],axis='columns')
merged
# Out:
#                 Car Model  Mileage  Age(yrs)  Sell Price($)  Audi A5  BMW X5  \
# 0                  BMW X5    69000         6          18000    False    True
# 1                  BMW X5    35000         3          34000    False    True
# 2                  BMW X5    57000         5          26100    False    True
# 3                  BMW X5    22500         2          40000    False    True
# 4                  BMW X5    46000         4          31500    False    True
# 5                 Audi A5    59000         5          29400     True   False
# 6                 Audi A5    52000         5          32000     True   False
# 7                 Audi A5    72000         6          19300     True   False
# 8                 Audi A5    91000         8          12000     True   False
# 9                 Audi A5    67000         6          22000     True   False
# 10  Mercedez Benz C class    83000         7          20000    False   False
# 11  Mercedez Benz C class    79000         7          21000    False   False
# 12  Mercedez Benz C class    59000         5          33000    False   False
# 13  Mercedez Benz C class    58780         4          27500    False   False
# 14  Mercedez Benz C class    82450         7          19400    False   False
# 15  Mercedez Benz C class    25400         3          40500    False   False
#
#     Mercedez Benz C class
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# 5                   False
# 6                   False
# 7                   False
# 8                   False
# 9                   False
# 10                   True
# 11                   True
# 12                   True
# 13                   True
# 14                   True
# 15                   True

# %%
final = merged.drop(['Car Model'], axis='columns')
final
# Out:
#     Mileage  Age(yrs)  Sell Price($)  Audi A5  BMW X5  Mercedez Benz C class
# 0     69000         6          18000    False    True                  False
# 1     35000         3          34000    False    True                  False
# 2     57000         5          26100    False    True                  False
# 3     22500         2          40000    False    True                  False
# 4     46000         4          31500    False    True                  False
# 5     59000         5          29400     True   False                  False
# 6     52000         5          32000     True   False                  False
# 7     72000         6          19300     True   False                  False
# 8     91000         8          12000     True   False                  False
# 9     67000         6          22000     True   False                  False
# 10    83000         7          20000    False   False                   True
# 11    79000         7          21000    False   False                   True
# 12    59000         5          33000    False   False                   True
# 13    58780         4          27500    False   False                   True
# 14    82450         7          19400    False   False                   True
# 15    25400         3          40500    False   False                   True

# %%
final = final.drop(['Mercedez Benz C class'], axis='columns')
final
# Out:
#     Mileage  Age(yrs)  Sell Price($)  Audi A5  BMW X5
# 0     69000         6          18000    False    True
# 1     35000         3          34000    False    True
# 2     57000         5          26100    False    True
# 3     22500         2          40000    False    True
# 4     46000         4          31500    False    True
# 5     59000         5          29400     True   False
# 6     52000         5          32000     True   False
# 7     72000         6          19300     True   False
# 8     91000         8          12000     True   False
# 9     67000         6          22000     True   False
# 10    83000         7          20000    False   False
# 11    79000         7          21000    False   False
# 12    59000         5          33000    False   False
# 13    58780         4          27500    False   False
# 14    82450         7          19400    False   False
# 15    25400         3          40500    False   False

# %%
X = final.drop('Sell Price($)', axis='columns')
X
# Out:
#     Mileage  Age(yrs)  Audi A5  BMW X5
# 0     69000         6    False    True
# 1     35000         3    False    True
# 2     57000         5    False    True
# 3     22500         2    False    True
# 4     46000         4    False    True
# 5     59000         5     True   False
# 6     52000         5     True   False
# 7     72000         6     True   False
# 8     91000         8     True   False
# 9     67000         6     True   False
# 10    83000         7    False   False
# 11    79000         7    False   False
# 12    59000         5    False   False
# 13    58780         4    False   False
# 14    82450         7    False   False
# 15    25400         3    False   False

# %%
y = final['Sell Price($)']

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict(X)
# Out:
# array([20113.37848985, 34548.608634  , 25206.86763644, 39853.40710449,
#        29877.73813522, 26850.15693272, 29808.48746739, 21334.04913832,
#        13260.1640842 , 23447.14237737, 19092.83191423, 20783.30650547,
#        29279.81020741, 29394.85168279, 19325.27217053, 43523.92751957])

# %%
model.score(X,y)
# Out:
# 0.9462236292879906

# %%
model.predict([[0,0,45000,4]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-1.09299745e+08])

# %%
# 2) Predict price of BMW X5
model.predict([[1,0,86000,7]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-2.08930285e+08])

# %%
# 3) Model accuracy score
model.score(X,y)
# Out:
# 0.9462236292879906
