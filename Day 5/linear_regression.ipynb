# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_excel("Smart_Factory_Machinery_Predictor_50K_Dataset.xlsx")

print(df.head())
# Out:
#     RPM  Vibration  Pressure        Mode  Temperature  Defective
# 0  4391         19        80    Standard          147          1
# 1  4512         19        53    Standard          134          1
# 2  4720         30        70  High-Speed          154          1
# 3  1816         12        44    Standard           66          0
# 4  1503         20        36    Standard           69          0

# %%
print(df.columns)
# Out:
# Index(['RPM', 'Vibration', 'Pressure', 'Mode', 'Temperature', 'Defective'], dtype='object')

# %%
df.shape
# Out:
# (50000, 6)

# %%
df.shape
# Out:
# (50000, 6)

# %%
X = df[["RPM"]]

y = df["Temperature"]

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

print(y_pred)
# Out:
# [144.27442833 146.68646964 150.83278858 ... 109.48920449 124.79868982
#  124.18072883]

# %%
mse = mean_squared_error(y, y_pred)

print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 202.58033740829643

# %%
plt.figure(figsize=(8,5))

plt.scatter(X, y)

plt.plot(X, y_pred)

plt.xlabel("RPM")
plt.ylabel("Temperature")

plt.title("Simple Linear Regression")

plt.show()
